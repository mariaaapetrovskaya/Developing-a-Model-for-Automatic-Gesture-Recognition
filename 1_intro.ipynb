# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaaapetrovskaya/Developing-a-Model-for-Automatic-Gesture-Recognition/blob/main/1_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Программирование на языке Python
# # Неделя 1.

# %% [markdown]
# ## Основные форматы файлов в Python
#
# 1. Файлы формата .py (скрипты)
#
# Это классические текстовые файлы с кодом Python. Код пишется от начала до конца. Чтобы запустить его нужно сохранить файл и сообщить интерпретатору: «Выполни это от первой строчки до последней». Код выполняется линейно. Если Вы допустили ошибку в 100-й строке, программа остановится, и вам придется исправлять и перезапускать всё сначала.
# Используются в бэкенде веб-сайтов, в десктопных приложениях, в больших промышленных проектах.
#
# 2. Файлы формата .ipynb (Jupyter Notebook) - мы будем называть его юпитеровский ноутбук или тетрадка
#
# Это «интерактивные тетради», которые делятся на маленькие ячейки. Вы можете выполнять код по частям. Внутри одной тетрадки могут быть не только код, но и текст, картинки, формулы.
# Используются в аналитике и в обучении.
#
# ## Ячейки
#
# **1. Кодовая ячейка (+ Code)**
#
# Внутри такой ячейки мы пишем команды на Python. Чтобы выполнить ячейку, нажмите Shift + Enter/Return.

# %%
# это кодовая ячейка
print("Hello, world!")
# сейчас мы написали функцию, которая напечатала наш текст в выводе
# Out:
# Hello, world!

# %%
# Чтобы "закомментировать" текст в кодовой ячейке — то есть сделать так, чтобы он НЕ выполнялся,
# нужно поставить решётку перед строкой

# если надо закомментировать сразу много строчек, можно выделить их и нажать Ctrl + / или Cmd + /
# раскомментировать можно так же!

# %% [markdown]
# **2. Текстовая ячейка (+ Markdown)**
#
# То, что вы читаете прямо сейчас — это текстовая ячейка. Внутри них мы пишем объяснения и формулы. Они не выполняются как код, а просто отображаются. Их можно форматировать!!!
#
# Попробуйте дважды кликнуть по этому тексту — вы увидите, как он написан "сырыми" символами (разметка Markdown). Нажмите Shift + Enter (или галочку), чтобы вернуть красивый вид.
#
# Текст в маркдаун можно форматировать. О том, как это делать, см. в конце тетрадки.

# %% [markdown]
# ## Среда программирования vs Python (интерпретатор)
#
# **Что такое Python (интерпретатор)?**
#
# Это программа, которая понимает ваш код и умеет его выполнять. Она установлена у вас на компьютере где-то в системной папке.
#
# Если у вас есть только Python, но нет редактора — вы можете писать код только в командной строке (это неудобно).
# Когда вы нажимаете «Запустить» в тетрадке, вы на самом деле просите эту программу выполнить ваш код.
# Проверим версию установленного у вас питона:

# %%
import sys
print(sys.version)
# Out:
# 3.12.0 (v3.12.0:0fb18b02c8, Oct  2 2023, 09:45:56) [Clang 13.0.0 (clang-1300.0.29.30)]

# %% [markdown]
# **Что такое cреда разработки или IDE - Integrated Development Environment?**
#
# Это интерфейс, в котором вы пишете код. Это как Microsoft Word для текста, но для кода. Среда не выполняет код сама — она передает его интерпретатору Python.
#
# Примеры сред:
# - VS Code (Visual Studio Code) — легкий редактор от Microsoft
# - PyCharm — среда для больших промышленных проектов от JetBrains
# - Jupyter (JupyterLab / Jupyter Notebook) — это тоже среда, но заточенная под интерактивную работу с тетрадками (.ipynb).
# - Google Colab — это Jupyter в облаке от Google. Работает прямо в браузере. Бесплатно дает доступ к GPU (графическим процессорам), что важно для обучения нейросетей. Есть интеграция с Google Диском.

# %% [markdown]
# ## Создание переменных.

# %% [markdown]
# В Python всё — это объект. У каждого объекта в Python есть свой индентификатор, тип и значение.
#
# 1. Идентификатор (id) — уникальный номер объекта в памяти компьютера. Это адрес, по которому объект "живет" в оперативной памяти, и он не меняется, пока объект существует
# 2. Тип (type) — определяет, что это за данные, какие операции с ними можно делать и сколько памяти они занимают. Например, числа можно складывать, а строки — склеивать.
# 3. Значение (value) — собственно то, что хранит объект. Для числа 5 значение — это 5.
#
#
# Типы данных:
# - число
# - строка
# - логический тип
#
# Структуры данных, т.е. объекты, содержащие несколько значений: список, множество, кортеж, словарь.
#
# В Python переменная — это не "коробка", в которую мы кладем значение. Это ссылка, которая указывает на объект в памяти. Оператор присваивания (=) не копирует объект, а создает ссылку на него. Он запоминает за именем переменной идентификатор объекта (id).
#
#
# Например, создадим переменную `a`, которой присвоим значение `1` (тип переменной — число):

# %%
a = 1          # создается объект 1, переменная a указывает на него
b = a          # b теперь указывает на ТОТ ЖЕ САМЫЙ объект, что и a

# %%
print(id(a))   # у вас будет другое число
print(id(b))   # ТО ЖЕ САМОЕ число! Это один и тот же объект
print(a is b)  # True — это проверка, что переменные указывают на один объект
# Out:
# 4393569800
# 4393569800
# True

# %% [markdown]
# Что происходит, когда мы меняем значение переменной? Мы перенаправляем ссылку на новый объект.

# %%
a += 1 # это то же самое, что a = a + 1
print(a, b) # теперь a ссылается на другой объект
print(id(a))
print(id(1))
print(id(2))
# Out:
# 2 1
# 4393569832
# 4393569800
# 4393569832

# %% [markdown]
# Переменные в  Python подчиняются следующим правилам:
#
# + имя переменной может содержать только буквенно-цифровые символы и символы подчеркивания (A-Za-z, 0–9 и _)
# + имя переменной <u>должно</u> начинаться с буквы или символа подчеркивания
# + имя переменной <u>не может</u> начинаться с цифры
# + в имени переменной <u>не должно</u> быть пробелов
# + имя <u>не должно</u> совпадать со служебными (зарезервированными) словами в Python
#
# > 1. Имена переменных чувствительны к регистру
#
# > 2. Рекомендуется давать переменным осмысленные названия
#
# Список зарезервированных слов можно узнать так:

# %%
import keyword
print(keyword.kwlist)

# %% [markdown]
# ## Типы данных. Числа
# Числа  в Python делятся на три вида:
#
# - `int` — только целые числа;
# - `float` — вещественные числа / числа с плавающей точкой
# - `complex` — комплексные числа

# %%
print(type(a))
print(type(1))
# применить функцию type() можно, как к самому объекту, так
# и к переменной, которая ссылается на объект
# Out:
# <class 'int'>
# <class 'int'>

# %%
print(type(1.2))
# Out:
# <class 'float'>

# %% [markdown]
# **Со всеми типами чисел вы можете выполнять разные функции:**
# * Сложение `x + 10`;
# * Вычитание `x - 10`;
# * Деление `x / 10`;
# * Деление нацело (без остатка после запятой) `x // 10`;
# * Остаток от деления на число `x % 3` (остаток от деления `x` на `3`);
# * Возведение в степень `x ** 2`.

# %% [markdown]
# ## Типы данных. Строки
#
# Текстовый тип данных обязательно заключается в кавычки.
#
# Python понимает и одинарные, и двойные кавычки. Главное правило: не закрывать одинарные кавычки двойными, и наоборот. Двойные кавычки закрывают двойные, одинарные — одинарные.

# %%
print(type('qwerty'))

# %%
# избегаем конфликта вложенных кавычек
text_1 = 'Лев Толстой очень любил играть на балалайке (и, конечно, детей), но не умел. Бывало, пишет роман «Война и мир», а сам думает: "Тень-дер-день-тер-тер-день-день-тень". Или: "Брам-пам-дам-дарарам-пам-пам".'


# если в тексте есть переносы строк, заключаем весь текст в тройные кавычки.
text_2 = '''Однажды Пушкин стрелялся с Гоголем. Пушкин говорит:
— Стреляй первый ты.
— Как ты? Нет, я!
— Ах, я! Нет, ты!
Так и не стали стреляться.'''

# %% [markdown]
# Вы можете также напечатать сразу несколько строк, используя функцию `print()`

# %%
print('Это первая строка', ', А это вторая строка')
# Out:
# Это первая строка , А это вторая строка

# %% [markdown]
# Можете напечатать с помощью print() одновременно и строку, и значение, сохраненное в определенную переменную.

# %%
name = 'Анастасия'
print('В переменную "name" сохранено имя', name)
# Out:
# В переменную "name" сохранено имя Анастасия

# %% [markdown]
# ### Ввод с клавиатуры
# Функция `input()`, которая позволяет запрашивать данные с клавиатуры, ВСЕГДА возвращает нам строки, даже если мы ввели число:

# %%
name = input()
print(name, type(name))
# Out:
#  <class 'str'>

# %%
# Вы можете поместить также в функцию `input()` строку, которая будет показываться пользователям при запуске кода
name = input('Введите свое имя: ')
print('Hello, ', name, '!', sep = "")
# sep = "" значит, что элементы будут печататься без пробелов
# как я об этом узнала?
# при наведении на функцию можно посмотреть, какие аргументы она принимает
# Out:
# Hello, Даша!

# %% [markdown]
# ## Задание
# Примите с клавиатуры Ваши имя и возраст и запишите эти значения в переменные name и age. Конвертируйте возраст в тип interger с помощью функции int().
# Напечатайте на каждой отдельной строке:
# 1. Ваше имя.
# 2. Сколько полных лет Вам будет через 10 лет.
# 3. Сколько полных лет вам было 5 лет назад.
# 4. Какое число получится, если разделить ваш возраст на 3.

# %%
pass

# %% [markdown]
# ## Типы данных. Логический тип данных (`bool`)
# Это неизменяемый тип, который имеет только два значения `True` и `False`.

# %%
print(type(True))
print(type(False))

# %% [markdown]
# `True` и `False` — результат проверки истинности утверждений. Например, у нас есть числа $2^6$ и $8^2$, и мы утверждаем, что первое больше второго. Так ли это?

# %%
print(2**6 > 8**2)
# Out:
# False

# %% [markdown]
# Проверим, может быть, $2^6$ меньше $8^2$?

# %%
print(2**6 < 8**2)
# Out:
# False

# %% [markdown]
# Проверим, равны ли числа

# %%
print(2**6 = 8**2)
# Out:
#   Input In [7]
#
#     print(2**6 = 8**2)
#
#           ^
#
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %% [markdown]
# Ошибка `SyntaxError` указывает нам, что знак `=` отвечает за присвоение значения. Для проверки эквивалентности значений используется двойной знак равенства `==`.

# %%
print(2**6 == 8**2)
# Out:
# True
# 64
# 64

# %% [markdown]
# <center>
#     <table>
#         <tr>
#             <th>Оператор сравнения</th>
#             <th> Интерпретация </th>
#         </tr>
#         <tr><td>&lt;</td><td> Первый операнд меньше второго </td></tr>
#         <tr><td>&gt;</td><td> Первый операнд больше второго</td></tr>
#         <tr><td>&lt;=</td><td> Меньше или равно</td></tr>
#         <tr><td>&gt;=</td><td> Больше или равно</td></tr>
#         <tr><td>==</td><td> Два операнда равны </td></tr>
#         <tr><td>!=</td><td> Два операнда не равны</td></tr>
#     </table>
# </center>

# %%
print(f'Если преобразовать True в целое число, то получится {int(True)}')
print(f'Если преобразовать False в целое число, то получится {int(False)}')
# Out:
# Если преобразовать True в целое число, то получится 1
# Если преобразовать False в целое число, то получится 0

# %% [markdown]
# Также важно понимать, что даже если визуально значения похожи, но типы их данных отличаются, то сравнение через оператор `==` выдаст `False`, например:

# %%
print(True == 'True')
# Out:
# False

# %% [markdown]
# ## Сложные логические выражения
#
# В Python 3 логических оператора:
#
# + `and` — логическое "И";
# + `or` — логическое "ИЛИ";
# + `not` — логическое отрицание.
#
#
# Предположим, следующую реальную ситуацию: в переменную `project` сохраняется оценка студента за проект, а в переменную `exam` — его же оценка, но уже за экзамен по курсу.
#
# 1. Если <u>хотя бы одна</u> оценка больше 8, то студент получает зачет. Как проверить, получил зачет студент или нет?
#
# Здесь нам поможет оператор `or`, который работает по такой схеме:
# + если хотя бы одна часть выражения принимает значение True, то в итоге выдается True;
# + если обе части выражения принимают значение False, то в итоге выдается False.

# %%
print(True or True)
print(True or False)
print(False or True)
print(False or False)
# Out:
# True
# True
# True
# False

# %%
project = int(input())
exam = int(input())

print(project > 8)
print(exam > 8)

print((project > 8) or (exam > 8)) # зачет получен
# Out:
# 4
# 9
# False
# True
# True

# %% [markdown]
# 2. Если <u>обе</u> оценки больше 8, то студент получает зачет.
#
# Здесь нам поможет оператор `and`, который работает по такой схеме:
# + если хотя бы одна часть выражения принимает значение False, то в итоге выдается False;
# + если обе части выражения принимают значение True, то в итоге выдается True.

# %%
print(True and True)
print(True and False)
print(False and True)
print(False and False)
# Out:
# True
# False
# False
# False

# %%
print((project > 8) and (exam > 8)) # ой, нет зачета
# Out:
# False

# %% [markdown]
# 3. Если <u>обе</u> оценки <u>ниже</u> 8, то студент получает незачет.
#
# В работе оператора `or` ничего не меняется. Оператор `not` представляет собой отрицание, то есть, например, если логическое выражение выдает `True`, но перед ним поставить `not`, оно будет выдавать `False`.

# %%
print(not((4 > 8) or (4 > 8))) # вот тут незачет
print(not((4 > 8) or (9 > 8)))
print(not((9 > 8) or (9 > 8)))
# Out:
# True
# False
# False

# %%
print(not((project > 8) or (exam > 8))) # незачета нет
# Out:
# False

# %% [markdown]
# Допускается использование и более сложных условий. Предположим, что ситуация такая: студент получает зачет, если выполняется хотя бы одно условие:
# + оценка за проект выше 8 и оценка за экзамен выше 8;
# + оценка за бонусное задание выше 9.

# %%
project = int(input())
exam = int(input())
bonus = int(input())

print(((project > 8) and (exam > 8)) or (bonus > 9))
# Out:
# 2
# 2
# 10
# True

# %% [markdown]
# ## Условные конструкции <a name="par3"></a>

# %% [markdown]
# Условные конструкции — конструкции с операторами условия. Условная конструкция обычно предполагает «развилку»: если условие выполняется, то должен выполняться один набор действий, если нет — другой набор действий.
#
# В этом контексте вам нужно запомнить три ключевых слова: `if`, `else`, `elif`.
#
# В ситуациях, когда у вас только две возможные развилки, вы будете использовать только `if` и `else`. Представим, что мы пишем программу которая будет на основании введенной оценки сообщать студенту, пойдет он на пересдачу по предмету или нет.

# %%
mark = int(input())

if mark >= 4: # если оценка больше или равна 4,
    print('Вы получили удовлетворительную оценку.') # печатаем эту строку
else: # во всех остальных случаях,
    print('Вы получили неудовлетворительную оценку. Вам будет назначена пересдача.') # печатай это
# Out:
# 5
# Вы получили удовлетворительную оценку.

# %% [markdown]
# Но вы также можете использовать ключевое слово `elif`. Оно используется в ситуациях когда вы хотите использовать несколько условий и усложнить ваш код. Приведем пример:
#
# * Если оценка студента за предмет меньше 4, он получает пересдачу по этому предмету и теряет стипендию;
# * Если оценка за предмет от 4 до 5 включительно, студент не получает пересдачу, но теряет стипендию;
# * Если оценка 6 и выше, студент не получает пересдачу и сохраняет стипендию.
#
# Программа, сообщающая студенту статус наличия пересдачи и сохранения стипендии, может выглядеть следующим образом:

# %%
mark = int(input()) # вводим значение, преобразуем его в целое число

if mark < 4: # если оценка меньше четырех, печатаем следующее:
    print('Вы получили пересдачу. Вы потеряли право получать стипендию.')
elif mark < 6: # если условие выше не удовлетворено и при этом оценка меньше 6, печатаем следующее:
    print('Вы не получили пересдачу, но потеряли право получать стипендию.')
else: # во всех остальных случаях, печатаем следующее:
    print('Вы не получили пересдачу, и сохранили вашу стипендию.')
# Out:
# 5
# Вы не получили пересдачу, но потеряли право получать стипендию.

# %% [markdown]
# Вы можете использовать какое угодно число `elif` в своём коде. Продемонстрируем на примере:
#
# Напишем программу, которая будет переводить оценку студента из 10-балльной системы в 5-балльную.

# %%
mark = int(input())

if mark >= 8:                    # если оценка больше или равна 8, то
    print('Отлично')             # печатаем "Отлично"
elif mark >= 6:                  # если оценка больше или равна 6 (но точно меньше 8), то
    print('Хорошо')              # печатаем "Хорошо"
elif mark > 4:                   # если оценка больше или равна 4 (но точно меньше 6), то
    print('Удовлетворительно')   # печатаем "Удовлетворительно"
else:                            # в остальных случаях (то есть оценка меньше 4)
    print('Неудовлетворительно') # печатаем "Неудовлетворительно"
# Out:
# 11
# Отлично

# %% [markdown]
# Предположим, что сотрудник учебного офиса использовал эту программу и ошибся — поставил 11 вместо 1. Непорядок. Надо исправлять. Давайте добавим дополнительную проверку на ввод числа — чтобы оно было строго от 0 до 10 включительно.

# %%
mark = int(input())

if (mark >= 0) and (mark <= 10):    # если оценка от 0 до 10, то проходит проверка:
    if mark >= 8:                     # если оценка больше или равна 8, то
        print('Отлично')              # печатаем "Отлично"
    elif mark >= 6:                   # если оценка больше или равна 6 (но точно меньше 8), то
        print('Хорошо')               # печатаем "Хорошо"
    elif mark > 4:                    # если оценка больше или равна 4 (но точно меньше 6), то
        print('Удовлетворительно')    # печатаем "Удовлетворительно"
    else:                             # в остальных случаях (то есть оценка меньше 4)
        print('Неудовлетворительно')  # печатаем "Неудовлетворительно"
else:                               # иначе (оценка меньше 0 или больше 10)
    print('Ошибка данных')          # печатаем "Ошибка данных"
# Out:
# 5
# Удовлетворительно

# %% [markdown]
# ## А ТЕПЕРЬ НАСТОЯЩАЯ ПРИЧИНА ПРИЙТИ НА СЕГОДНЯШНИЙ СЕМИНАР

# %%
# запустите ячейку
import antigravity

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# ____
# ## Оформление кода, или В каком виде надо сдавать тетрадки
#
# Код должны читать не только компьютеры, но и люди (ваши коллеги, я и вы сами через месяц). В мире Python есть официальный гайд по стилю — [PEP 8](https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html).
#
# Вот основные правила для начала:
#
# **1. Правила именования**
#
# Переменные и функции мы называем строчными буквами, слова разделяем подчеркиванием (snake_case).
#
# ✅ user_name = "Анна"
#
# ✅ def calculate_sum():
#
#
# Константы (значения, которые не меняются): пишем ЗАГЛАВНЫМИ с подчеркиванием.
#
# ✅ MAX_LENGTH = 100
#
#
# Классы (будем изучать позже): пишем с заглавной буквы, слова слитно (CamelCase).
#
# ✅ class TextProcessor:
#
#
# **2. Отступы и пробелы**
#
# Ставьте пробелы вокруг операторов:
#
# ✅ x = 5 + 3
#
# ❌ x=5+3
#
# После запятой ставьте пробел:
#
# ✅ my_list = [1, 2, 3]
#
# ❌ my_list = [1,2,3]
#
# **3. Комментарии**
#
# Однострочный комментарий начинается с # (ставьте пробел после решетки):
# ```{python}
# # Это комментарий, Python его игнорирует
# ```
# Текстовыми ячейками документируйте этапы работы, решётками — сложные куски кода.

# %% [markdown]
# ## Форматирование Markdown
#
# **1. Заголовки: оформляются решётками.**
# ```
# # Заголовок 1-го уровня
# ## Заголовок 2-го уровня
# ### Заголовок 3-го уровня
# ```
#
# **2. Списки**
#
# Нумерованный:
# ```
# 1. Первый пункт
# 2. Второй пункт
#    1. Подпункт (с отступом в 4 пробела)
# ```
# Маркированный (точки/звездочки):
# ```
# - Элемент списка
# - Еще элемент
#   - Вложенный элемент (отступ)
# ```
# Вместо "-" можно использовать "*"
#
# **3. Выделение текста**
# ```
# *курсив* или _курсив_
# **жирный** или __жирный__
# ***жирный курсив***
# ~~зачеркнутый~~
# ```
#
# **4. Ссылки и картинки**
# ```
# [Текст ссылки](https://www.python.org)
# ![Подпись к картинке](путь_к_картинке.png)
# ```
#
# **5. Вставка больших блоков кода (с подсветкой)**
# Чтобы вставить код в текстовую ячейку (просто для показа, не для выполнения), используйте тройные обратные кавычки и укажите язык: (```python):
#
# ```python
# print("Этот код не выполняется")
# ```
#
# **6. Таблицы**
# ```
# | Столбец 1 | Столбец 2 |
# |-----------|-----------|
# | Ячейка 1  | Ячейка 2  |
# | Данные    | Еще данные |
# ```
# Получится так:
# | Столбец 1 | Столбец 2 |
# |-----------|-----------|
# | Ячейка 1  | Ячейка 2  |
# | Данные    | Еще данные |
#
# **7. Горизонтальная линия-разделитель**
#
# Три нижних подчёркивания:
# ```
# ___
# ```
# Получится так:
# ___
#
# А ещё можно вставлять формулы и многое другое!

# %% [markdown]
# ## Дополнительные материалы
#
# + Документация Python [Built-in Types](https://docs.python.org/3/library/stdtypes.html)
# + Курс на платформе Stepik «Python: основы и применение» ([ссылка на курс](https://stepik.org/course/512/syllabus))
# + Щуров И.В., Тамбовцева А.А., Жучкова С.В. —  курс «Основы программирования в Python» ([ссылка на курс](https://allatambov.github.io/pypolit/pypolit.html))
# + Как работают числа с плавающей точкой? [YouTube](https://www.youtube.com/watch?v=U0U8Ddx4TgE)
# + Jupyter Notebook Markdown [Tutorial](https://www.datacamp.com/tutorial/markdown-in-jupyter-notebook)
